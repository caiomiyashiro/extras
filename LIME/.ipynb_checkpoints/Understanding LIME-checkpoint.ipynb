# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('breast-cancer-wisconsin.csv', index_col=0)
df = df.iloc[:,:-1]
df.head()
# Out:
#          diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# id
# 842302           M        17.99         10.38          122.80     1001.0
# 842517           M        20.57         17.77          132.90     1326.0
# 84300903         M        19.69         21.25          130.00     1203.0
# 84348301         M        11.42         20.38           77.58      386.1
# 84358402         M        20.29         14.34          135.10     1297.0
#
#           smoothness_mean  compactness_mean  concavity_mean  \
# id
# 842302            0.11840           0.27760          0.3001
# 842517            0.08474           0.07864          0.0869
# 84300903          0.10960           0.15990          0.1974
# 84348301          0.14250           0.28390          0.2414
# 84358402          0.10030           0.13280          0.1980
#
#           concave points_mean  symmetry_mean           ...             \
# id                                                     ...
# ...

# %%
df_train = df.drop('diagnosis', axis=1, inplace=False)
target = [1 if elem == 'M' else 0 for elem in df['diagnosis']]

# %%
from tpot import TPOTClassifier

X_train, X_test, y_train, y_test = train_test_split(df_train, target,
                                                    train_size=0.75, test_size=0.25)

tpot = TPOTClassifier(generations=5, population_size=20, verbosity=2)
tpot.fit(X_train, y_train)
print(tpot.score(X_test, y_test))
# Out:
# ...
# Generation 1 - Current best internal CV score: 0.97187414500684
# Generation 2 - Current best internal CV score: 0.97187414500684
# Generation 3 - Current best internal CV score: 0.97187414500684
# Generation 4 - Current best internal CV score: 0.97187414500684
# Generation 5 - Current best internal CV score: 0.97187414500684
#
# Best pipeline: LinearSVC(MinMaxScaler(input_matrix), C=25.0, dual=True, loss=hinge, penalty=l2, tol=0.01)
# 0.965034965034965

# %%
tpot.predict_proba
